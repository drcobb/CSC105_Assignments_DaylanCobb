# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("titanic_data.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       2    male  27.0      0      0  13.0000        S  Second
# 885         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
class_survived = df[df['survived'] == 1].groupby('class')['survived'].count()

# %%
average_fare_by_town = df.groupby('embark_town')['fare'].mean().reset_index()
average_fare_by_town.rename(columns={'fare': 'Average Fare'}, inplace=True)

# %%
average_fare_by_sex_and_town = df.groupby(['embark_town', 'sex'])['fare'].mean()

# %%
average_fare_age_by_sex_and_town = df.groupby(['embark_town', 'sex'])[['fare', 'age']].mean()

# %%
class_survived #1
# Out:
# class
# First     136
# Second     87
# Third     119
# Name: survived, dtype: int64

# %%
average_fare_by_town #2
# Out:
#    embark_town  Average Fare
# 0    Cherbourg     59.954144
# 1   Queenstown     13.348741
# 2  Southampton     27.109647

# %%
average_fare_by_sex_and_town #3
# Out:
# embark_town  sex
# Cherbourg    female    75.169805
#              male      48.262109
# Queenstown   female    12.634958
#              male      13.991145
# Southampton  female    38.740929
#              male      21.743397
# Name: fare, dtype: float64

# %%
average_fare_age_by_sex_and_town #4
# Out:
#                          fare        age
# embark_town sex
# Cherbourg   female  75.169805  28.344262
#             male    48.262109  32.998841
# Queenstown  female  12.634958  24.291667
#             male    13.991145  30.937500
# Southampton female  38.740929  27.771505
#             male    21.743397  30.292234
