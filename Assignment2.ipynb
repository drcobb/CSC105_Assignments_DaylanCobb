# %%
import pandas as pd

# %%
df = pd.read_csv('car_crashes.csv')

rows, columns = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")

df.head()

column_names = df.columns
print(column_names)

description = df.describe()
print(description)

info = df.info()

quantitative_stats = df.describe()

qualitative_stats = df.describe(include=['object'])

subset = df[['CRASH DATE', 'CRASH TIME', 'BOROUGH']]
# Out:
# C:\Users\Landon\AppData\Local\Temp\ipykernel_14676\2786729595.py:5: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('car_crashes.csv')
# Number of rows: 2018963
# Number of columns: 29
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
# ...
